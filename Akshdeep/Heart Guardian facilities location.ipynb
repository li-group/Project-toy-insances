# %% [markdown]
# ### Problem: Heart Guardian facilities location, Optimization in Operations Research (OIOR), Application 13.5
#
# Reference: Optimization in Operations Research (2nd edition) by Ronald L. Rardin
#
# The Heart Guardian (HG) corporation is establishing a logistic network to distribute its new single line of monitoring devices across 5 markets. Distribution centers from which trucks will deliver the monitors will need to be established at any or all of 3 already selected sites. Demands in each market (thousands), unit shipping costs from each site to each market (in dollars), and setup costs (in thousand dollars) to establish each site have been estimated as shown in the following table.
#
# ![aa.png](attachment:aa.png)
#
# HG wishes to develop a minimum cost plan over these parameters. Thus, formulate and solve an approprite MILP formulation to achieve the objective.

# %%
from pyomo.environ import *
import pyomo.environ as pe

model = ConcreteModel()

# Parameters
d = {
    1:75,2:90,3:81,4:26,5:57,
}

f = {
    1:400,
    2:250,
    3:300,
}

c = {
    (1,1): 4,  (1,2): 7, (1,3): 3,  (1,4): 12, (1,5): 15,
    (2,1): 13, (2,2): 11, (2,3): 17, (2,4): 9,  (2,5): 19,
    (3,1): 8,  (3,2): 12, (3,3): 10, (3,4): 7,  (3,5): 5,
}
